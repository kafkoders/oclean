# %%
import pandas as pd
import numpy as np

# %%
import pickle

# %%
import random

# %%
def generate_data(lenght, width, samples=0.2):
    dimension = lenght * width
    
    df = pd.DataFrame(columns=['x', 'y', 'trash'])
    
    data = np.array([[i, j] for i in range(0, lenght) for j in range(0, width)])
    
    df['x'] = data[:, 0]
    df['y'] = data[:, 1]
    
    chances = [0]*8 + [1]*2
    trash = [random.choice(chances) for _ in range(dimension)]
    df['trash'] = trash
    
    return df

# %%
res = generate_data(2000, 2000)

# %%
res.reset_index(drop=True, inplace=True)

# %%
with open('test_data.pickle', 'wb') as data:
    pickle.dump(res, data)

# %%
import matplotlib.pyplot as plt

import seaborn as sns
sns.set(style='whitegrid')

# %%
plt.figure(figsize=(20,10))
table = res.pivot('y', 'x', 'trash')
ax = sns.heatmap(table)
ax.invert_yaxis()
plt.show()
